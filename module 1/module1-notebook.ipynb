# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
fruits_df = pd.read_csv('fruit_data_with_colors.txt', sep='\t')

# %%
fruits_df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
fruits_df.shape
# Out:
# (59, 7)

# %% [markdown]
# # Creating train_test split

# %%
X = fruits_df[['mass', 'width', 'height', 'color_score']]
Y = fruits_df['fruit_label']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
X_train.shape
# Out:
# (44, 3)

# %%
y_train.shape
# Out:
# (44,)

# %%
X_test.shape
# Out:
# (15, 3)

# %%
y_test.shape
# Out:
# (15,)

# %% [markdown]
# # Examining the data

# %%
from matplotlib import cm

cmap = cm.get_cmap('gnuplot')
scatter = pd.scatter_matrix(X_train, c=y_train, marker='o', s=40, hist_kwds={'bins':15}, figsize=(12, 12), cmap=cmap)
# Out:
# /home/djaballah/PythonEnv/PFE/lib/python3.5/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   after removing the cwd from sys.path.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train['width'], X_train['height'], X_train['color_score'], c= y_train, marker='o', s=100)
ax.set_xlabel('Width')
ax.set_ylabel('Height')
ax.set_zlabel('Color Score')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Creating the classifier object

# %%
from sklearn.neighborse import Kn
